# %% [markdown]
# # Velib in Paris

# %% [markdown]
# <b>Objectif :</b> augmenter l’offre de stationnement vélo
#
# Recherche possible:
# -        Visualiser l’existant :  positionnement du stationnement vélo, nombre de place, densité à l’IRIS (Ilots Regroupés pour l’Information Statistique) et par arrondissement….
# -        Identifier les principaux équipements et commerces qui ne présentent pas de stationnement vélo à proximité immédiate (moins de 50 mètres)  et éventuellement avoir une indication de la distance du stationnement le plus proche.
# -        Identifier par zone (à l’IRIS ?/par arrondissement…)  le nombre actuel de place de stationnement vélo, et l’écart par rapport à la demande moyenne parisienne – sur la base des données INSEE à l’IRIS et de l’utilisation du système vélib ‘.

# %% [markdown]
# ## Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install GeoPandas
# Out:
# Collecting GeoPandas
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 3.0 MB/s
# Collecting shapely>=1.6
#   Downloading Shapely-1.8.1.post1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 74.0 MB/s
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.3.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 17.6 MB/s
# Requirement already satisfied: pandas>=0.25.0 in /home/romain/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from GeoPandas) (1.3.4)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.21-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.6 MB)
#      |████████████████████████████████| 16.6 MB 34.6 MB/s
# Requirement already satisfied: attrs>=17 in /home/romain/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from fiona>=1.8->GeoPandas) (21.2.0)
# Requirement already satisfied: click>=4.0 in /home/romain/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from fiona>=1.8->GeoPandas) (7.1.2)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: six>=1.7 in /home/romain/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from fiona>=1.8->GeoPandas) (1.14.0)
# Requirement already satisfied: setuptools in /home/romain/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from fiona>=1.8->GeoPandas) (56.0.0)
# Requirement already satisfied: certifi in /home/romain/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from fiona>=1.8->GeoPandas) (2021.10.8)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: numpy>=1.17.3 in /home/romain/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from pandas>=0.25.0->GeoPandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/romain/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from pandas>=0.25.0->GeoPandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/romain/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from pandas>=0.25.0->GeoPandas) (2021.3)
# Installing collected packages: munch, cligj, click-plugins, shapely, pyproj, fiona, GeoPandas
# Successfully installed GeoPandas-0.10.2 click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.21 munch-2.5.0 pyproj-3.3.0 shapely-1.8.1.post1
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/romain/.pyenv/versions/3.8.12/envs/lewagon/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import geopandas as gpd
import folium

# %% [markdown]
# ### Import dataset

# %%
arrive = pd.read_excel('../data/2021_S1_Stations_arrivees_Paris.xlsx')
arrive.head()
# Out:
#            Month_name                   Unnamed: 1  Janvier  Février     Mars  \
# 0  Code de la station         Arrivées par station  Valeurs  Valeurs  Valeurs
# 1             0000002    Station Fermeture Système      NaN      NaN      NaN
# 2               10001      René Boulanger - Lancry     4059     4218     4531
# 3               10003  Hauteville - Bonne Nouvelle     2563     2645     3337
# 4               10004  Metz - Faubourg Saint-Denis     5205     4899     6584
#
#      Avril      Mai     Juin  Juillet
# 0  Valeurs  Valeurs  Valeurs  Valeurs
# 1      NaN      NaN      NaN      NaN
# 2     3830     4234     5890     5125
# 3     2764     3999     5170     4126
# 4     6421     7162     9054     7677

# %%
depart = pd.read_excel('../data/2021_S1_Stations_departs_Paris.xlsx')
depart.head()
# Out:
#            Month_name                               Unnamed: 1  Janvier  \
# 0  Code de la station                      Départs par station  Valeurs
# 1               10001                  René Boulanger - Lancry     4059
# 2               10003              Hauteville - Bonne Nouvelle     2513
# 3               10004              Metz - Faubourg Saint-Denis     5172
# 4               10005  Petites Ecuries - Faubourg Poissonnière     2949
#
#    Février     Mars    Avril      Mai     Juin  Juillet
# 0  Valeurs  Valeurs  Valeurs  Valeurs  Valeurs  Valeurs
# 1     4131     4517     3833     4181     5819     5008
# 2     2611     3384     2759     3932     5128     4108
# 3     4814     6412     6312     7063     8965     7655
# 4     2891     3856     3259     3845     5147     4032

# %%
emplacement = pd.read_csv('../data/velib-emplacement-des-stations.csv', sep=';')
emplacement.head()
# Out:
#   Identifiant station                Nom de la station  \
# 0               11025                Froment - Bréguet
# 1                6029   Vaugirard - Monsieur le Prince
# 2                7025      Octave Gréard - Tour Eiffel
# 3                9028                 Moncey - Blanche
# 4               10042  Enghien - Faubourg Poissonnière
#
#    Capacité de la station              Coordonnées géographiques
# 0                      43      48.8570414504784,2.37289470306807
# 1                      26  48.848951441614176,2.3411329463124275
# 2                      33   48.856502977695634,2.293178754328878
# 3                      17   48.88006587474148,2.3310810327529907
# 4                      16    48.87242006305313,2.348395236282807

# %%
real_time = pd.read_csv('../data/velib_disponibilite_en_temps_reel.csv', sep=';')

# %%
real_time = real_time[['Identifiant station', 'Vélos mécaniques disponibles', 'Vélos électriques disponibles']]
real_time.columns = ['station_id', 'mecanique_dispo_nb', 'electrique_dispo_nb']
real_time.head()
# Out:
#   station_id  mecanique_dispo_nb  electrique_dispo_nb
# 0       9020                   0                    0
# 1      16107                   2                    2
# 2      12109                  18                    5
# 3      11104                   0                    1
# 4       6003                   6                    6

# %% [markdown]
# ## Datasets modifs

# %% [markdown]
# ### Emplacement

# %%
# Création des colonnes latitude et longitude pour les coordonnées de chaques stations
emplacement['lat'] = emplacement['Coordonnées géographiques'].apply(lambda x: float(x.split(',')[0]))
emplacement['lon'] = emplacement['Coordonnées géographiques'].apply(lambda x: float(x.split(',')[1]))

# %%
# Renommer les colonnes
emplacement.columns = ['station_id', 'station_name', 'station_capacity', 'Coordonnées géographiques', 'lat', 'lon']

# %%
emplacement.head()
# Out:
#   station_id                     station_name  station_capacity  \
# 0      11025                Froment - Bréguet                43
# 1       6029   Vaugirard - Monsieur le Prince                26
# 2       7025      Octave Gréard - Tour Eiffel                33
# 3       9028                 Moncey - Blanche                17
# 4      10042  Enghien - Faubourg Poissonnière                16
#
#                Coordonnées géographiques        lat       lon
# 0      48.8570414504784,2.37289470306807  48.857041  2.372895
# 1  48.848951441614176,2.3411329463124275  48.848951  2.341133
# 2   48.856502977695634,2.293178754328878  48.856503  2.293179
# 3   48.88006587474148,2.3310810327529907  48.880066  2.331081
# 4    48.87242006305313,2.348395236282807  48.872420  2.348395

# %% [markdown]
# ### Arrive

# %%
arrive.head()
# Out:
#            station_id                  station_nom Janvier_arrive  \
# 0  Code de la station         Arrivées par station        Valeurs
# 1             0000002    Station Fermeture Système            NaN
# 2               10001      René Boulanger - Lancry           4059
# 3               10003  Hauteville - Bonne Nouvelle           2563
# 4               10004  Metz - Faubourg Saint-Denis           5205
#
#   Février_arrive Mars_arrive Avril_arrive Mai_arrive Juin_arrive  \
# 0        Valeurs     Valeurs      Valeurs    Valeurs     Valeurs
# 1            NaN         NaN          NaN        NaN         NaN
# 2           4218        4531         3830       4234        5890
# 3           2645        3337         2764       3999        5170
# 4           4899        6584         6421       7162        9054
#
#   Juillet_arrive
# 0        Valeurs
# 1            NaN
# 2           5125
# 3           4126
# 4           7677

# %%
# Renommer les colonnes
arrive.columns = ['station_id', 'station_nom', 'Janvier_arrive', 'Février_arrive', 'Mars_arrive', 'Avril_arrive', 'Mai_arrive', 'Juin_arrive', 'Juillet_arrive']

# %%
# Enlever les deux premières colonnes inutiles
arrive_df = arrive.drop(axis=1, index=[0,1])
arrive_df.head()
# Out:
#   station_id                              station_nom Janvier_arrive  \
# 2      10001                  René Boulanger - Lancry           4059
# 3      10003              Hauteville - Bonne Nouvelle           2563
# 4      10004              Metz - Faubourg Saint-Denis           5205
# 5      10005  Petites Ecuries - Faubourg Poissonnière           2987
# 6      10006   Petites Ecuries - Faubourg Saint-Denis           6301
#
#   Février_arrive Mars_arrive Avril_arrive Mai_arrive Juin_arrive  \
# 2           4218        4531         3830       4234        5890
# 3           2645        3337         2764       3999        5170
# 4           4899        6584         6421       7162        9054
# 5           2935        3846         3332       3890        5202
# 6           5862        7537         6939       8200       10811
#
#   Juillet_arrive
# 2           5125
# 3           4126
# 4           7677
# 5           4073
# 6           9021

# %% [markdown]
# ### depart

# %%
depart.head()
# Out:
#            Month_name                               Unnamed: 1  Janvier  \
# 0  Code de la station                      Départs par station  Valeurs
# 1               10001                  René Boulanger - Lancry     4059
# 2               10003              Hauteville - Bonne Nouvelle     2513
# 3               10004              Metz - Faubourg Saint-Denis     5172
# 4               10005  Petites Ecuries - Faubourg Poissonnière     2949
#
#    Février     Mars    Avril      Mai     Juin  Juillet
# 0  Valeurs  Valeurs  Valeurs  Valeurs  Valeurs  Valeurs
# 1     4131     4517     3833     4181     5819     5008
# 2     2611     3384     2759     3932     5128     4108
# 3     4814     6412     6312     7063     8965     7655
# 4     2891     3856     3259     3845     5147     4032

# %%
# Renommer les colonnes
depart.columns = ['station_id', 'station_nom', 'Janvier_depart', 'Février_depart', 'Mars_depart', 'Avril_depart', 'Mai_depart', 'Juin_depart', 'Juillet_depart']

# %%
# Enlever la première colonnes inutile
depart_df = depart.drop(axis=1, index=0)
depart_df.head()
# Out:
#   station_id                              station_nom Janvier_depart  \
# 1      10001                  René Boulanger - Lancry           4059
# 2      10003              Hauteville - Bonne Nouvelle           2513
# 3      10004              Metz - Faubourg Saint-Denis           5172
# 4      10005  Petites Ecuries - Faubourg Poissonnière           2949
# 5      10006   Petites Ecuries - Faubourg Saint-Denis           6317
#
#   Février_depart Mars_depart Avril_depart Mai_depart Juin_depart  \
# 1           4131        4517         3833       4181        5819
# 2           2611        3384         2759       3932        5128
# 3           4814        6412         6312       7063        8965
# 4           2891        3856         3259       3845        5147
# 5           5823        7567         6822       8111       10832
#
#   Juillet_depart
# 1           5008
# 2           4108
# 3           7655
# 4           4032
# 5           8971

# %% [markdown]
# ## Stations sur map

# %% [markdown]
# Création d'une carte avec toutes les stations représentées par des balises bleus.
# Utilisation de la libray folium.
# Problème: Trop de stations donc inutile

# %%
map_osm = folium.Map(location=[48.85, 2.34])
# folium.Marker(emplacement['Coordonnées géographiques'][0].split(','), popup=emplacement['Nom de la station'][0]).add_to(map_osm)
for point in range(0, len(emplacement['Coordonnées géographiques'])):
    folium.Marker(emplacement['Coordonnées géographiques'][point].split(','), popup=emplacement['station_name'][point]).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_398549b2d689408cbcbc6a65156a0656%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_398549b2d689408cbcbc6a65156a0656%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_398549b2d689408cbcbc6a65156a0656%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_398549b2d689408cbcbc6a65156a0656%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B48.85%2C%202.34%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20c ...

# %% [markdown]
# <b>Solution :</b>
# Utilisation de <a href="https://kepler.gl/">Kepler website</a>.
# Résultat visible sur le powerpoint.

# %% [markdown]
# ## Velib stations

# %%
arrive_df.head()
# Out:
#   station_id                              station_nom Janvier_arrive  \
# 2      10001                  René Boulanger - Lancry           4059
# 3      10003              Hauteville - Bonne Nouvelle           2563
# 4      10004              Metz - Faubourg Saint-Denis           5205
# 5      10005  Petites Ecuries - Faubourg Poissonnière           2987
# 6      10006   Petites Ecuries - Faubourg Saint-Denis           6301
#
#   Février_arrive Mars_arrive Avril_arrive Mai_arrive Juin_arrive  \
# 2           4218        4531         3830       4234        5890
# 3           2645        3337         2764       3999        5170
# 4           4899        6584         6421       7162        9054
# 5           2935        3846         3332       3890        5202
# 6           5862        7537         6939       8200       10811
#
#   Juillet_arrive
# 2           5125
# 3           4126
# 4           7677
# 5           4073
# 6           9021

# %%
depart_df.head()
# Out:
#   station_id                              station_nom Janvier_depart  \
# 1      10001                  René Boulanger - Lancry           4059
# 2      10003              Hauteville - Bonne Nouvelle           2513
# 3      10004              Metz - Faubourg Saint-Denis           5172
# 4      10005  Petites Ecuries - Faubourg Poissonnière           2949
# 5      10006   Petites Ecuries - Faubourg Saint-Denis           6317
#
#   Février_depart Mars_depart Avril_depart Mai_depart Juin_depart  \
# 1           4131        4517         3833       4181        5819
# 2           2611        3384         2759       3932        5128
# 3           4814        6412         6312       7063        8965
# 4           2891        3856         3259       3845        5147
# 5           5823        7567         6822       8111       10832
#
#   Juillet_depart
# 1           5008
# 2           4108
# 3           7655
# 4           4032
# 5           8971

# %%
# Merge des bases de données d'arrivées et de départs des vélibs à chaque stations
velibs_df = arrive_df.merge(depart_df, how='inner', on=['station_id', 'station_nom']).dropna()

# %%
velibs_df.head(1)
# Out:
#   station_id              station_nom Janvier_arrive Février_arrive  \
# 0      10001  René Boulanger - Lancry           4059           4218
#
#   Mars_arrive Avril_arrive Mai_arrive Juin_arrive Juillet_arrive  \
# 0        4531         3830       4234        5890           5125
#
#   Janvier_depart Février_depart Mars_depart Avril_depart Mai_depart  \
# 0           4059           4131        4517         3833       4181
#
#   Juin_depart Juillet_depart
# 0        5819           5008

# %%
# Calcul de la différence entre les arrivées et départs de chaque stations
velibs_df['Janvier_diff'] = velibs_df['Janvier_arrive'] - velibs_df['Janvier_depart']
velibs_df['Février_diff'] = velibs_df['Février_arrive'] - velibs_df['Février_depart']
velibs_df['Mars_diff'] = velibs_df['Mars_arrive'] - velibs_df['Mars_depart']
velibs_df['Avril_diff'] = velibs_df['Avril_arrive'] - velibs_df['Avril_depart']
velibs_df['Mai_diff'] = velibs_df['Mai_arrive'] - velibs_df['Mai_depart']
velibs_df['Juin_diff'] = velibs_df['Juin_arrive'] - velibs_df['Juin_depart']
velibs_df['Juillet_diff'] = velibs_df['Juillet_arrive'] - velibs_df['Juillet_depart']

# %%
velibs_df.head()
# Out:
#   station_id                              station_nom Janvier_arrive  \
# 0      10001                  René Boulanger - Lancry           4059
# 1      10003              Hauteville - Bonne Nouvelle           2563
# 2      10004              Metz - Faubourg Saint-Denis           5205
# 3      10005  Petites Ecuries - Faubourg Poissonnière           2987
# 4      10006   Petites Ecuries - Faubourg Saint-Denis           6301
#
#   Février_arrive Mars_arrive Avril_arrive Mai_arrive Juin_arrive  \
# 0           4218        4531         3830       4234        5890
# 1           2645        3337         2764       3999        5170
# 2           4899        6584         6421       7162        9054
# 3           2935        3846         3332       3890        5202
# 4           5862        7537         6939       8200       10811
#
#   Juillet_arrive Janvier_depart Février_depart Mars_depart Avril_depart  \
# 0           5125           4059           4131        4517         3833
# 1           4126           2513           2611        3384         2759
# 2           7677           5172           4814        6412         6312
# 3           4073           2949           2891        3856         3259
# 4           9021           6317           5823        7567         6822
#
#   Mai_depart Juin_depart Juillet_depart
# 0       4181        5819           5008
# 1       3932        5128           4108
# 2       7063        8965           7655
# 3       3845        5147           4032
# 4       8111       10832           8971

# %%
# Plot des différences pour chaques mois pour les 35 premières stations
plt.figure(figsize=(15,5))
plt.plot(velibs_df['station_nom'][0:35], velibs_df['Janvier_diff'][0:35], label='Janvier')
plt.plot(velibs_df['station_nom'][0:35], velibs_df['Février_diff'][0:35], label='Février')
plt.plot(velibs_df['station_nom'][0:35], velibs_df['Mars_diff'][0:35], label='Mars')
plt.plot(velibs_df['station_nom'][0:35], velibs_df['Avril_diff'][0:35], label='Avril')
plt.plot(velibs_df['station_nom'][0:35], velibs_df['Mai_diff'][0:35], label='Mai')
plt.plot(velibs_df['station_nom'][0:35], velibs_df['Juin_diff'][0:35], label='Juin')
plt.plot(velibs_df['station_nom'][0:35], velibs_df['Juillet_diff'][0:35], label='Juillet')
plt. xticks(rotation=90)
plt.legend();

# %%
# Calcul de la moyenne des différences par station
# La moyenne a été choisi car les "diff" sont similaires pour chaque mois
velibs_df['diff_mean'] = np.mean(velibs_df[['Janvier_diff', 'Février_diff', 'Mars_diff', 'Avril_diff', 'Mai_diff', 'Juin_diff', 'Juillet_diff']], axis=1).apply(lambda x: int(x))

# %%
# Merge avec le base de données emplacement
velibs_stations = velibs_df[['station_id', 'station_nom', 'diff_mean']].merge(emplacement[['station_id', 'station_capacity', 'Coordonnées géographiques', 'lat', 'lon']], how='inner', on='station_id')
velibs_stations.head()
# Out:
#   station_id                              station_nom  diff_mean  \
# 0      10001                  René Boulanger - Lancry         48
# 1      10003              Hauteville - Bonne Nouvelle         24
# 2      10004              Metz - Faubourg Saint-Denis         87
# 3      10005  Petites Ecuries - Faubourg Poissonnière         40
# 4      10006   Petites Ecuries - Faubourg Saint-Denis         32
#
#    station_capacity             Coordonnées géographiques        lat       lon
# 0                62                  48.8685433,2.3600032  48.868543  2.360003
# 1                17   48.87077436024043,2.349649636832728  48.870774  2.349650
# 2                48                    48.870893,2.353521  48.870893  2.353521
# 3                18   48.87397217237368,2.348388757504776  48.873972  2.348389
# 4                28  48.87287120589831,2.3542150855064397  48.872871  2.354215

# %%
# Ajout du nombre de vélibs mécaniques et électriques pour chaque stations au 05 Mars 2022
velibs_stations = velibs_stations.merge(real_time, how='left', on='station_id')
velibs_stations.head()
# Out:
#   station_id                              station_nom  diff_mean  \
# 0      10001                  René Boulanger - Lancry         48
# 1      10003              Hauteville - Bonne Nouvelle         24
# 2      10004              Metz - Faubourg Saint-Denis         87
# 3      10005  Petites Ecuries - Faubourg Poissonnière         40
# 4      10006   Petites Ecuries - Faubourg Saint-Denis         32
#
#    station_capacity             Coordonnées géographiques        lat  \
# 0                62                  48.8685433,2.3600032  48.868543
# 1                17   48.87077436024043,2.349649636832728  48.870774
# 2                48                    48.870893,2.353521  48.870893
# 3                18   48.87397217237368,2.348388757504776  48.873972
# 4                28  48.87287120589831,2.3542150855064397  48.872871
#
#         lon  mecanique_dispo_nb  electrique_dispo_nb
# 0  2.360003                  22                   21
# 1  2.349650                   3                    1
# 2  2.353521                   7                    5
# 3  2.348389                   1                    3
# 4  2.354215                   1                    1

# %%
# Calcul du ratio des velibs mécaniques et électriques par station
velibs_stations['mecanique_ratio'] = round(velibs_stations['mecanique_dispo_nb'] / (velibs_stations['electrique_dispo_nb'] + velibs_stations['mecanique_dispo_nb']), 2)
velibs_stations['electrique_ratio'] = round(velibs_stations['electrique_dispo_nb'] / (velibs_stations['electrique_dispo_nb'] + velibs_stations['mecanique_dispo_nb']), 2)
velibs_stations.head()
# Out:
#   station_id                              station_nom  diff_mean  \
# 0      10001                  René Boulanger - Lancry         48
# 1      10003              Hauteville - Bonne Nouvelle         24
# 2      10004              Metz - Faubourg Saint-Denis         87
# 3      10005  Petites Ecuries - Faubourg Poissonnière         40
# 4      10006   Petites Ecuries - Faubourg Saint-Denis         32
#
#    station_capacity             Coordonnées géographiques        lat  \
# 0                62                  48.8685433,2.3600032  48.868543
# 1                17   48.87077436024043,2.349649636832728  48.870774
# 2                48                    48.870893,2.353521  48.870893
# 3                18   48.87397217237368,2.348388757504776  48.873972
# 4                28  48.87287120589831,2.3542150855064397  48.872871
#
#         lon  mecanique_dispo_nb  electrique_dispo_nb  mecanique_ratio  \
# 0  2.360003                  22                   21             0.51
# 1  2.349650                   3                    1             0.75
# 2  2.353521                   7                    5             0.58
# 3  2.348389                   1                    3             0.25
# 4  2.354215                   1                    1             0.50
#
#    electrique_ratio
# 0              0.49
# 1              0.25
# 2              0.42
# 3              0.75
# 4              0.50

# %%
# Sauvegarder cette nouvelle base de données en csv pour analyse sur le site kepler.gl
velibs_stations.to_csv('../data/velibs_stations.csv')
